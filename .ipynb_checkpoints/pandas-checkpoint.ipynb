# %%
import pandas as pd

# %%
dt=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data')

# %%
dt.shape,dt.dtypes
# Out:
# ((698, 11), 1000025     int64
#  5           int64
#  1           int64
#  1.1         int64
#  1.2         int64
#  2           int64
#  1.3        object
#  3           int64
#  1.4         int64
#  1.5         int64
#  2.1         int64
#  dtype: object)

# %%
dt.columns=list('abcdefghij')+['class']

# %%
dt.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'class'], dtype='object')

# %%
dt.to_csv('bcancer.csv')

# %%
dt1=pd.read_csv('https://bit.ly/imdbratings')

# %%
dt1.shape
# Out:
# (979, 6)

# %%
type(dt1)
# Out:
# pandas.core.frame.DataFrame

# %%
dt1.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
dt1.tail()
# Out:
#      star_rating                                            title  \
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# ...

# %%
dt1=pd.read_csv('https://bit.ly/imdbratings',nrows=100,usecols=[1,3,4])

# %%
dt1.shape
# Out:
# (100, 3)

# %%
import pandas as pd
dt1=pd.read_csv('https://bit.ly/imdbratings')

# %%
dt1.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
dt1['duration']
# Out:
# 0      142
# 1      175
# 2      200
# 3      152
# 4      154
# 5       96
# 6      161
# 7      201
# 8      195
# 9      139
# 10     178
# 11     148
# 12     124
# 13     142
# 14     179
# 15     169
# 16     133
# 17     207
# 18     146
# 19     121
# 20     136
# 21     130
# 22     130
# 23     106
# 24     127
# 25     116
# 26     175
# 27     118
# 28     110
# 29      87
#       ...
# 949    103
# 950    108
# 951    105
# 952    117
# 953    102
# 954    104
# 955    157
# 956    104
# 957     98
# 958    109
# 959     96
# 960    103
# 961    114
# 962     99
# 963    118
# 964    150
# 965    105
# 966     87
# 967    136
# 968    162
# 969    109
# 970    107
# 971     90
# 972    112
# 973    126
# 974    116
# 975    118
# 976    138
# 977    114
# 978    126
# Name: duration, Length: 979, dtype: int64

# %%
x=dt1.duration>200
dt1[x]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %%
dt1[dt1.duration>200]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %%
dt1[(dt1.duration>200) & (dt1.genre=='Adventure')]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 85              PG  Adventure       216
# 142             PG  Adventure       224
# 204              G  Adventure       212
# 445       APPROVED  Adventure       220
#
#                                            actors_list
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 85   [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 204  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 445  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...

# %%
dt1[(dt1.duration>200) & ((dt1.genre=='Adventure')|(dt1.genre=='Crime'))]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 78               R      Crime       229
# 85              PG  Adventure       216
# 142             PG  Adventure       224
# 204              G  Adventure       212
# 445       APPROVED  Adventure       220
#
#                                            actors_list
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 78   [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85   [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# ...

# %%
dt1[(dt1.duration>200) & (dt1.genre.isin(['Crime','Adventure','Action']))]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 78               R      Crime       229
# 85              PG  Adventure       216
# 142             PG  Adventure       224
# 204              G  Adventure       212
# 445       APPROVED  Adventure       220
# 767       APPROVED     Action       205
#
#                                            actors_list
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# ...

# %%
dt1.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
dt1.genre.nunique()
# Out:
# 16

# %%
dt1[(dt1.duration>200)][dt1.genre=='Drama']
# Out:
# C:\Users\amit\AppData\Local\Programs\Python\Python36-32\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
dt1.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
dt1.genre.value_counts(normalize=True)*100
# Out:
# Drama        28.396323
# Comedy       15.934627
# Action       13.891726
# Crime        12.665986
# Biography     7.865169
# Adventure     7.660878
# Animation     6.332993
# Horror        2.962206
# Mystery       1.634321
# Western       0.919305
# Thriller      0.510725
# Sci-Fi        0.510725
# Film-Noir     0.306435
# Family        0.204290
# Fantasy       0.102145
# History       0.102145
# Name: genre, dtype: float64

# %%
dt1.star_rating.max(),dt1.star_rating.min(),dt1.star_rating.mean()
# Out:
# (9.3000000000000007, 7.4000000000000004, 7.8897854954034736)

# %%
dt1.star_rating.agg(['min','sum','count','mean','max'])
# Out:
# min         7.400000
# sum      7724.100000
# count     979.000000
# mean        7.889785
# max         9.300000
# Name: star_rating, dtype: float64

# %%
dt1.star_rating.describe()
# Out:
# count    979.000000
# mean       7.889785
# std        0.336069
# min        7.400000
# 25%        7.600000
# 50%        7.800000
# 75%        8.100000
# max        9.300000
# Name: star_rating, dtype: float64

# %%
dt1[dt1.genre=='Drama'][['star_rating','duration']].agg(['min','mean','max'])
# Out:
#       star_rating    duration
# min      7.400000   64.000000
# mean     7.902518  126.539568
# max      8.900000  242.000000

# %%
dt1[dt1.genre=='Drama'].agg(['min','mean','max'])
# Out:
#       star_rating         title content_rating  genre    duration  \
# min      7.400000  12 Angry Men       APPROVED  Drama   64.000000
# mean     7.902518           NaN            NaN    NaN  126.539568
# max      8.900000          Zulu              X  Drama  242.000000
#
#                                             actors_list
# min     [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# mean                                                NaN
# max   [u'William Holden', u'Gloria Swanson', u'Erich...

# %%
dt1[dt1.genre=='Drama'].describe()
# Out:
#        star_rating    duration
# count   278.000000  278.000000
# mean      7.902518  126.539568
# std       0.328041   25.637086
# min       7.400000   64.000000
# 25%       7.600000  108.000000
# 50%       7.900000  123.000000
# 75%       8.100000  138.000000
# max       8.900000  242.000000

# %%
dt1.groupby('genre').star_rating.describe()
# Out:
#            count      mean       std  min    25%   50%    75%  max
# genre
# Action     136.0  7.884559  0.333084  7.4  7.600  7.80  8.100  9.0
# Adventure   75.0  7.933333  0.361802  7.4  7.650  7.90  8.100  8.9
# Animation   62.0  7.914516  0.292444  7.4  7.700  7.90  8.100  8.6
# Biography   77.0  7.862338  0.310364  7.4  7.600  7.80  8.100  8.9
# Comedy     156.0  7.822436  0.304922  7.4  7.600  7.80  8.000  8.6
# Crime      124.0  7.916935  0.392143  7.4  7.600  7.80  8.100  9.3
# Drama      278.0  7.902518  0.328041  7.4  7.600  7.90  8.100  8.9
# Family       2.0  7.850000  0.070711  7.8  7.825  7.85  7.875  7.9
# Fantasy      1.0  7.700000       NaN  7.7  7.700  7.70  7.700  7.7
# Film-Noir    3.0  8.033333  0.305505  7.7  7.900  8.10  8.200  8.3
# History      1.0  8.000000       NaN  8.0  8.000  8.00  8.000  8.0
# Horror      29.0  7.806897  0.337989  7.4  7.500  7.70  8.000  8.6
# Mystery     16.0  7.975000  0.387298  7.4  7.575  8.10  8.225  8.6
# ...

# %%
dt1.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
dt1[dt1.actors_list.str.contains('Khan')]
# Out:
#      star_rating                              title content_rating      genre  \
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 89           8.4                             Swades      NOT RATED      Drama
# 93           8.4        Dilwale Dulhania Le Jayenge      NOT RATED     Comedy
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 336          8.0                         Life of Pi             PG  Adventure
# 373          8.0                    My Name Is Khan          PG-13      Drama
# 718          7.6                    The Kite Runner          PG-13      Drama
#
#      duration                                        actors_list
# ...

# %%
a='print("hello")'
eval(a)
# Out:
# hello

# %%
ac=[]
for i in dt1.actors_list:
    ac.extend(eval(i))

# %%
len(ac)
# Out:
# 2937

# %%
len(set(ac))
# Out:
# 1777

# %%
pd.Series(ac).value_counts()
# Out:
# Robert De Niro         18
# Clint Eastwood         14
# Tom Hanks              14
# Brad Pitt              14
# Al Pacino              13
# Johnny Depp            12
# Christian Bale         11
# Dustin Hoffman         11
# Leonardo DiCaprio      11
# Harrison Ford          10
# James Stewart          10
# Denzel Washington      10
# Julianne Moore         10
# Ethan Hawke             9
# Jack Nicholson          9
# Ed Harris               9
# Russell Crowe           9
# Sean Connery            9
# Bruce Willis            8
# Morgan Freeman          8
# Cary Grant              8
# Ian McKellen            8
# Robert Downey Jr.       8
# Tom Cruise              8
# Michael Caine           8
# Matt Damon              8
# Jake Gyllenhaal         8
# Sean Penn               8
# Kate Winslet            8
# Tony Chiu Wai Leung     7
#                        ..
# Victor Sjöström         1
# Paul Dano               1
# Craig Parkinson         1
# Danai Gurira            1
# ...

# %%
import pandas as pd

# %%
#dt=pd.read_table('https://bit.ly/chiporders')
dt=pd.read_csv('https://bit.ly/chiporders',sep='\t')

# %%
dt.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
dt[dt.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 42          20         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# 110         49         1  Chicken Bowl
# 123         54         1  Chicken Bowl
# 138         62         1  Chicken Bowl
# 140         63         1  Chicken Bowl
# 142         64         1  Chicken Bowl
# 154         70         2  Chicken Bowl
# 160         73         1  Chicken Bowl
# 176         79         1  Chicken Bowl
# 182         82         1  Chicken Bowl
# 193         86         1  Chicken Bowl
# 199         89         1  Chicken Bowl
# 206         92         1  Chicken Bowl
# 209         93         1  Chicken Bowl
# 211         93         1  Chicken Bowl
# ...

# %%
dt[dt.item_name.str.lower().str.contains('chicken')]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# 16           8         1       Chicken Burrito
# 17           9         1       Chicken Burrito
# 19          10         1          Chicken Bowl
# 23          12         1       Chicken Burrito
# 26          13         1          Chicken Bowl
# 29          15         1       Chicken Burrito
# 35          18         1    Chicken Soft Tacos
# 36          18         1    Chicken Soft Tacos
# 42          20         1          Chicken Bowl
# 44          20         1    Chicken Salad Bowl
# 45          21         1       Chicken Burrito
# 52          24         1       Chicken Burrito
# 63          28         1       Chicken Burrito
# 68          30         1       Chicken Burrito
# ...

# %%
dt[dt.item_name.str.contains('Chicken')]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# 16           8         1       Chicken Burrito
# 17           9         1       Chicken Burrito
# 19          10         1          Chicken Bowl
# 23          12         1       Chicken Burrito
# 26          13         1          Chicken Bowl
# 29          15         1       Chicken Burrito
# 35          18         1    Chicken Soft Tacos
# 36          18         1    Chicken Soft Tacos
# 42          20         1          Chicken Bowl
# 44          20         1    Chicken Salad Bowl
# 45          21         1       Chicken Burrito
# 52          24         1       Chicken Burrito
# 63          28         1       Chicken Burrito
# 68          30         1       Chicken Burrito
# ...

# %%
dt.item_price=dt.item_price.str.lstrip('$')

# %%
dt.item_price=dt.item_price.astype(dtype='f')

# %%
dt[dt.item_name.str.contains('Chicken')].item_price.describe()
# Out:
# count    1560.000000
# mean       10.133764
# std         2.718119
# min         8.190000
# 25%         8.750000
# 50%         8.750000
# 75%        11.250000
# max        35.000000
# Name: item_price, dtype: float64

# %%
dt2=pd.read_csv('https://bit.ly/drinksbycountry')

# %%
dt2[0:1]
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia

# %%
dt2.loc[0]
# Out:
# country                         Afghanistan
# beer_servings                             0
# spirit_servings                           0
# wine_servings                             0
# total_litres_of_pure_alcohol              0
# continent                              Asia
# Name: 0, dtype: object

# %%
dt2.iloc[77]
# Out:
# country                         India
# beer_servings                       9
# spirit_servings                   114
# wine_servings                       0
# total_litres_of_pure_alcohol      2.2
# continent                        Asia
# Name: 77, dtype: object

# %%
dt2.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
dt2.set_index('country',inplace=True)  #inplace apply the changes locally
# chetavani baar baar na chalye

# %%
dt2.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Tanzania', 'USA', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=193)

# %%
dt2.loc['India'] #index based indexing
# Out:
# beer_servings                      9
# spirit_servings                  114
# wine_servings                      0
# total_litres_of_pure_alcohol     2.2
# continent                       Asia
# Name: India, dtype: object

# %%
dt2.iloc[77] # positional indexing
# Out:
# beer_servings                      9
# spirit_servings                  114
# wine_servings                      0
# total_litres_of_pure_alcohol     2.2
# continent                       Asia
# Name: India, dtype: object
