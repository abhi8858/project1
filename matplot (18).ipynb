# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('ggplot')
a=np.arange(1,50,0.1)
b=np.sin(a)
plt.plot(a,b,'+',color='blue',label='sin')
plt.plot(a,np.cos(a),'>',color='green',label='cos')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('sample-graph')
plt.legend() # if we have labels in plot then use legend or it will give error
plt.show()

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  '_classic_test']

# %%
x=[2,5,3,6,1,4]
y=[9,5,8,4,2,12]
plt.scatter(x,y,marker='x',s=150,alpha=1,color='blue',label='points')
plt.xlabel('x-label')
plt.ylabel('y-label')
plt.title('grah')
plt.legend()
plt.show()

# %%
p=[4,23,4,5,7,6,8,9,12,23,14,15,12,19,17,18,19,24,25,26,27,22,21,19,10]
r=[1,10,20,30]
plt.hist(p,r,histtype='bar',rwidth=0.4)
plt.show()

# %%
x=['india','australia','uk','usa','japan','china']
y=[9,6,5,10,8,9]
plt.bar(x,y)
plt.show()

# %%
x=['india','australia','uk','usa','japan','china']
y=[9,6,5,10,8,9]
plt.pie(y,labels=x,shadow=True,explode=(0.1,0,0,0.20,0,0),autopct='%0.2f',colors=['b','g','y','c','w','m'])
plt.legend(loc='lower right')
plt.show()

# %%
x=[1,2,3,4,5]
y=[12,3,6,5,3]
y1=[9,4,7,8,4]
y2=[8,9,9,6,7]
plt.stackplot(x,y,y1,y2)
plt.show()

# %%
x=[1,2,3,4,5]
y=[12,3,6,5,3]
p=plt.subplot(2,2,1)
p.plot(x,y)
p1=plt.subplot(2,2,2)
p1.scatter(x,y)
p2=plt.subplot(223)
p2.bar(x,y)
p3=plt.subplot(2,2,4)
p3.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dt=pd.read_csv("https://bit.ly/drinksbycountry")

# %%
dt.groupby('continent').country.count().plot(kind='bar')
plt.show()

# %%
dt.groupby('continent').beer_servings.describe().plot(kind='bar')

# %%
dt1=pd.read_excel('f:/data/others/titanic3.xls')

# %%
dt1.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
dt1.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
for i in dt1.columns:
    if dt1[i].dtypes==object:
        d=dict.fromkeys(dt1[i])
        for j,k in enumerate(d):
            d[k]=j
        dt1[i]=list(map(d.get,dt1[i]))

# %%
dt1.head()
# Out:
#    pclass  survived  name  sex      age  sibsp  parch  ticket      fare  \
# 0       1         1     0    0  29.0000      0      0       0  211.3375
# 1       1         1     1    1   0.9167      1      2       1  151.5500
# 2       1         0     2    0   2.0000      1      2       1  151.5500
# 3       1         0     3    1  30.0000      1      2       1  151.5500
# 4       1         0     4    0  25.0000      1      2       1  151.5500
#
#    cabin  embarked  boat   body  home.dest
# 0      0         0     0    NaN          0
# 1      1         0     1    NaN          1
# 2      1         0     2    NaN          1
# 3      1         0     2  135.0          1
# 4      1         0     2    NaN          1

# %%
dt1.corr()
# Out:
#              pclass  survived      name       sex       age     sibsp  \
# pclass     1.000000 -0.312469  0.898045  0.124617 -0.408106  0.060832
# survived  -0.312469  1.000000 -0.293815 -0.528693 -0.055513 -0.027825
# name       0.898045 -0.293815  1.000000  0.124638 -0.344054  0.065576
# sex        0.124617 -0.528693  0.124638  1.000000  0.063646 -0.109609
# age       -0.408106 -0.055513 -0.344054  0.063646  1.000000 -0.243699
# sibsp      0.060832 -0.027825  0.065576 -0.109609 -0.243699  1.000000
# parch      0.018322  0.082660  0.003625 -0.213125 -0.150917  0.373587
# ticket     0.884093 -0.288419  0.990327  0.118899 -0.337135  0.071868
# fare      -0.558629  0.244265 -0.481470 -0.185523  0.178739  0.160238
# cabin     -0.486116  0.219149 -0.361108 -0.093948  0.183244 -0.018347
# embarked   0.097287  0.070274  0.102670 -0.120213  0.038022 -0.070435
# boat      -0.062632  0.724194 -0.076928 -0.350062 -0.093704 -0.036742
# ...

# %%
import seaborn as sb

# %%
import matplotlib.pyplot as plt

# %%
sb.countplot(x='survived',data=dt1)

# %%
sb.boxplot(x='pclass',y='age',data=dt1)

# %%
sb.boxplot(x='pclass',y='fare',data=dt1)

# %%
sb.pairplot(data=dt1.dropna(axis=1))
